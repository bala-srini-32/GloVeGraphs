# %%
import numpy as np
import networkx as nx
import gensim
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import silhouette_score
from scipy.spatial.distance import cdist, pdist
import pickle

from sklearn.metrics import normalized_mutual_info_score as NMI
# %matplotlib inline

# %%
def getNMI(folder,num):
    path = 'data/'+folder+'/'
    emb_file = path+'embedding_run_'+str(num)+'.emb'
    community_file = path+'community_run_'+str(num)+'.dat'
    graph_file = path+'network_run_'+str(num)+'.dat'
    W = pickle.load(open(emb_file, "rb" ))
    G = nx.read_edgelist(graph_file)
    nodes = G.number_of_nodes()
    emb = (W[0:nodes,:] + W[nodes:,:])/2.0
    community_truth_values = []
    for line in open(community_file):
        cols = line.split()
        community_truth_values.append(cols[1])
    num_clusters = len(set(community_truth_values))
    kmeans = KMeans(n_clusters=num_clusters).fit(emb)
    return NMI(community_truth_values,kmeans.labels_)

# %%
def getAverageNMI(folder):
    avg = 0
    for i in range(1,51):
        avg += getNMI(folder,i)
    return avg/50.0

# %%
getNMI('mu_0.4_N_1000',1)
# Out:
# 0.29423255903055451

# %%
#W = pickle.load(open("../node2vec-master/emb/embedding_run_1.emb", "rb" ))
G = nx.read_edgelist('../node2vec-master/graph/network_run_1.dat')

# %%
model = gensim.models.KeyedVectors.load_word2vec_format('../node2vec-master/emb/cppoutput')
emb = []
#vertex_list = G.nodes_iter()
vertex_list = sorted(map(lambda x : int(x),G.nodes()))
for i in vertex_list:
    emb.append(model.word_vec(str(i)))
emb = np.asarray(emb)

# %%
G.nodes()
# Out:
# [u'452',
#  u'198',
#  u'818',
#  u'819',
#  u'346',
#  u'347',
#  u'340',
#  u'341',
#  u'342',
#  u'343',
#  u'810',
#  u'811',
#  u'812',
#  u'813',
#  u'814',
#  u'349',
#  u'816',
#  u'817',
#  u'719',
#  u'718',
#  u'717',
#  u'716',
#  u'715',
#  u'714',
#  u'713',
#  u'712',
#  u'711',
#  u'710',
#  u'915',
#  u'420',
#  u'606',
#  u'423',
#  u'736',
#  u'422',
#  u'195',
#  u'425',
#  u'619',
#  u'910',
#  u'913',
#  u'298',
#  u'299',
#  u'296',
#  u'297',
#  u'294',
#  u'295',
#  u'292',
#  u'293',
#  u'290',
#  u'291',
#  u'591',
#  u'590',
#  u'593',
#  u'592',
#  u'595',
#  u'594',
#  u'597',
#  u'596',
#  u'599',
#  u'598',
#  u'197',
#  u'196',
#  u'191',
#  u'190',
#  u'193',
#  u'192',
#  u'270',
#  u'271',
#  u'272',
#  u'273',
#  u'274',
#  u'275',
#  u'276',
#  u'277',
#  u'278',
#  u'279',
#  u'569',
#  u'374',
#  u'344',
#  u'524',
#  u'525',
#  u'526',
#  u'527',
#  u'520',
#  u'521',
#  u'522',
#  u'523',
#  u'528',
#  u'529',
#  u'449',
#  u'448',
# ...

# %%
vectors = []
doc = open("../node2vec-master/emb/cppoutput","r")
for line in doc:
    a = line.split()
    tmp = []
    for l in a:
        tmp.append(float(l))
    vectors.append(tmp)
doc.close()
del vectors[0]

ordered = sorted(vectors, key=lambda x: x[0])
for o in ordered:
    del o[0] #remove node id
emb = ordered

# %%
len(vectors)
# Out:
# 129002

# %%
nodes = G.number_of_nodes()

# %%
#emb = (W[0:nodes,:] + W[nodes:,:])/2.0
#emb = W[:nodes,:]
#emb.shape

# %%
from pylab import rcParams
rcParams['figure.figsize'] = 10, 10

#pos=nx.spring_layout(G)
pos = nx.spring_layout(G)
nx.draw_networkx_nodes(G,pos,
                       nodelist=d[0],
                       node_color='green',
                       node_size=500,
                   alpha=0.8,label=d[0])
nx.draw_networkx_nodes(G,pos,
                       nodelist=d[1],
                       node_color='orange',
                       node_size=500,
                   alpha=0.8,label=d[1])

nx.draw_networkx_labels(G,pos)
nx.draw_networkx_edges(G,pos,width=1.0,alpha=0.5)

# %%
communities = []
for line in open('../node2vec-master/emb/community_run_1.dat'):
    cols = line.split()
    communities.append((cols[0],cols[1]))

# %%
community_truth_values = [x[1] for x in communities]

# %%
num_clusters = len(set(community_truth_values))
num_clusters
# Out:
# 33

# %%
from collections import defaultdict
d = defaultdict(list)
kmeans = KMeans(n_clusters=num_clusters).fit(emb)
for i,j in enumerate(kmeans.labels_):
    d[j].append(str(i+1))

# %%
NMI(community_truth_values,kmeans.labels_)
# Out:
# 0.9683048613341515

# %%
import os

# %%
os.walk('Data').next()[1]
# Out:
# ['mu_0.05_N_1000',
#  'mu_0.0_N_1000',
#  'mu_0.15_N_1000',
#  'mu_0.1_N_1000',
#  'mu_0.25_N_1000',
#  'mu_0.2_N_1000',
#  'mu_0.35_N_1000',
#  'mu_0.3_N_1000',
#  'mu_0.45_N_1000',
#  'mu_0.4_N_1000',
#  'mu_0.55_N_1000',
#  'mu_0.5_N_1000',
#  'mu_0.65_N_1000',
#  'mu_0.6_N_1000',
#  'mu_0.75_N_1000',
#  'mu_0.7_N_1000',
#  'mu_0.85_N_1000',
#  'mu_0.8_N_1000',
#  'mu_0.95_N_1000',
#  'mu_0.9_N_1000']

# %%
np.arange(0.3,1,0.1)
# Out:
# array([ 0.3,  0.4,  0.5,  0.6,  0.7,  0.8,  0.9])

# %%
folder = 'mu_0.4_N_1000'
path = 'data/'+folder+'/'
graph_file = path+'network_run_1.dat'
G = nx.read_edgelist(graph_file)

# %%
graph_file
# Out:
# 'data/mu_0.4_N_1000/network_run_1.dat'

# %%
import graph2vec.trainer
graph2vec = Graph2Vec(vector_dimensions=128)
graph2vec.parse_graph(graph_file, extend_paths=2)
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-7-5d3e4ad82425> in <module>()
#       1 import graph2vec.trainer
# ----> 2 import graph2vec.Graph2Vec
#       3 graph2vec = Graph2Vec(vector_dimensions=128)
#       4 graph2vec.parse_graph(graph_file, extend_paths=2)
#
# ImportError: No module named Graph2Vec
